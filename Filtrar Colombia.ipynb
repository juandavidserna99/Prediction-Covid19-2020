# %%
import pandas as pd

df = pd.read_csv('C:/Users/juand/OneDrive/Escritorio/Predicción/10-24-2020.csv', header=0)
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2020-10-25 04:24:36  33.93911
# 1   NaN    NaN            NaN        Albania  2020-10-25 04:24:36  41.15330
# 2   NaN    NaN            NaN        Algeria  2020-10-25 04:24:36  28.03390
# 3   NaN    NaN            NaN        Andorra  2020-10-25 04:24:36  42.50630
# 4   NaN    NaN            NaN         Angola  2020-10-25 04:24:36 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953      40768    1511      34023   5234.0  Afghanistan
# 1  20.168300      18858     473      10548   7837.0      Albania
# 2   1.659600      55880    1907      38932  15041.0      Algeria
# 3   1.521800       4038      69       2729   1240.0      Andorra
# 4  17.873900       9026     267       3461   5298.0       Angola
#
#    Incidence_Rate  Case-Fatality_Ratio
# 0      104.725758             3.706338
# ...

# %%
df2 = df[df['Country_Region'] == 'Colombia']

# %%
df2.to_csv('C:/Users/juand/OneDrive/Escritorio/Predicción/10-24-2020.csv')
